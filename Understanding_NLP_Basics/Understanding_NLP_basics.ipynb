# %%
#Text Extraction
import urllib2
from bs4 import BeautifulSoup

# %%
articleURL = "https://www.washingtonpost.com/technology/2018/09/25/google-overhauls-search-show-more-pictures-videos-context/?utm_term=.8e020cd38187"

# %%
page = urllib2.urlopen(articleURL).read().decode('utf8','ignore') 
soup = BeautifulSoup(page,"lxml")
soup
# Out:
# <!DOCTYPE html>\n<html class="story layout_article pb_actual_layout_article rendering-context-www outputtype_default-article" lang="en"> <head> <script>window.pbDeferredScripts=window.pbDeferredScripts||new Array;</script> <script id="_$cookiemonster">(function(document,undefined){var wl={};wl.reg=[];wl.map=[];function CM(wlmap,wlreg){this.wl={map:wl.map.concat(wlmap||[]),reg:wl.reg.concat(wlreg||[])}}CM.prototype.ommNom=function(){return this.nom(true,undefined)};CM.prototype.allows=function(cookieKey){var yum=this.nom(false,[cookieKey]).indexOf(cookieKey)>-1;return!yum};CM.prototype.nom=function(deleteCookies,cookiesList){var unset=[];var domainkey=document.location.hostname.split("").reverse().join("").slice(0,18),dcookies=cookiesList||document.cookie.split(";"),\ndcookie,save,reg;for(var i=0;i<dcookies.length,dcookie=dcookies[i];i++){save=dcookie.trim().split("\\x3d")[0].toLowerCase();if(this.wl.map.indexOf(save)>-1);else unset.push(save)}for(var o=0;o<this.wl.reg.length,reg=this
# ...

# %%
soup.find('article')
# Out:
# <article class="paywall" itemprop="articleBody"> <div class="inline-content inline-photo inline-photo-normal" data-elm-loc="0"> <a name="77WDGOWAG4I6RH2PUG326JK2UU"></a> <img class="unprocessed " data-hi-res-src="https://www.washingtonpost.com/resizer/QbXTn2szP_QlqGVYDhLXRCwDgpg=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/77WDGOWAG4I6RH2PUG326JK2UU.jpg" data-low-res-src="https://www.washingtonpost.com/resizer/ONNFJqJo3ZWUDboa2Jxe22raPOQ=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/77WDGOWAG4I6RH2PUG326JK2UU.jpg" data-raw-src="https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/77WDGOWAG4I6RH2PUG326JK2UU.jpg" data-threshold="480" src="https://www.washingtonpost.com/resizer/ONNFJqJo3ZWUDboa2Jxe22raPOQ=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/77WDGOWAG4I6RH2PUG326JK2UU.jpg"/><br/> <span class="pb-caption">Google demonstrates its newest search features, include activity cards, smart videos and
# ...

# %%
soup.find('article').text
# Out:
# u'    Google demonstrates its newest search features, include activity cards, smart videos and Google Lens, at its 20th-anniversary event on Sunday in San Francisco. (Amy Osborne/AFP/Getty Images) (AMY OSBORNE/AFP/Getty Images)       By  Hamza Shaban          Hamza Shaban Technology reporter  Email  Bio  Follow         September 25  Google has unveiled a host of updates to its search product, designed to make visual information more useful as pictures and video become more central to the Internet experience. The new features showing up in searches include introductory videos about public figures, topic videos to help users plan trips or learn about new subjects, and an overhaul of its ranking system for displaying image-based searches, offering users more context and easier ways to shop online. Previously a stand-alone app, Google Lens uses artificial intelligence to identify the contents of a picture without needing words to figure out what it is. Now, Google will integrate Lens dir
# ...

# %%
text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
text
# Out:
# u'    Google demonstrates its newest search features, include activity cards, smart videos and Google Lens, at its 20th-anniversary event on Sunday in San Francisco. (Amy Osborne/AFP/Getty Images) (AMY OSBORNE/AFP/Getty Images)       By  Hamza Shaban          Hamza Shaban Technology reporter  Email  Bio  Follow         September 25  Google has unveiled a host of updates to its search product, designed to make visual information more useful as pictures and video become more central to the Internet experience. The new features showing up in searches include introductory videos about public figures, topic videos to help users plan trips or learn about new subjects, and an overhaul of its ranking system for displaying image-based searches, offering users more context and easier ways to shop online. Previously a stand-alone app, Google Lens uses artificial intelligence to identify the contents of a picture without needing words to figure out what it is. Now, Google will integrate Lens dir
# ...

# %%
text.encode('ascii', errors='replace').replace("?"," ")
# Out:
# '    Google demonstrates its newest search features, include activity cards, smart videos and Google Lens, at its 20th-anniversary event on Sunday in San Francisco. (Amy Osborne/AFP/Getty Images) (AMY OSBORNE/AFP/Getty Images)       By  Hamza Shaban          Hamza Shaban Technology reporter  Email  Bio  Follow         September 25  Google has unveiled a host of updates to its search product, designed to make visual information more useful as pictures and video become more central to the Internet experience. The new features showing up in searches include introductory videos about public figures, topic videos to help users plan trips or learn about new subjects, and an overhaul of its ranking system for displaying image-based searches, offering users more context and easier ways to shop online. Previously a stand-alone app, Google Lens uses artificial intelligence to identify the contents of a picture without needing words to figure out what it is. Now, Google will integrate Lens dire
# ...

# %%
#Text Extraction Function
def getTextFromWebsite(url):
    page = urllib2.urlopen(url).read().decode('utf8')
    soup = BeautifulSoup(page,"lxml")
    text = ' '.join(map(lambda p: p.text, soup.find_all('article')))
    return text.encode('ascii', errors='replace').replace("?"," ")

# %%
getTextFromWebsite('https://www.washingtonpost.com/technology/2018/09/25/google-overhauls-search-show-more-pictures-videos-context/?utm_term=.8e020cd38187')
# Out:
# '    Google demonstrates its newest search features, include activity cards, smart videos and Google Lens, at its 20th-anniversary event on Sunday in San Francisco. (Amy Osborne/AFP/Getty Images) (AMY OSBORNE/AFP/Getty Images)       By  Hamza Shaban          Hamza Shaban Technology reporter  Email  Bio  Follow         September 25  Google has unveiled a host of updates to its search product, designed to make visual information more useful as pictures and video become more central to the Internet experience. The new features showing up in searches include introductory videos about public figures, topic videos to help users plan trips or learn about new subjects, and an overhaul of its ranking system for displaying image-based searches, offering users more context and easier ways to shop online. Previously a stand-alone app, Google Lens uses artificial intelligence to identify the contents of a picture without needing words to figure out what it is. Now, Google will integrate Lens dire
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/lakshyasi/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Tokenization
import nltk
text="Knowledge is knowing a tomato is a fruit. Wisdom is not putting it in a fruit salad"
from nltk.tokenize import word_tokenize, sent_tokenize
sents=sent_tokenize(text)
print(sents)
# Out:
# ['Knowledge is knowing a tomato is a fruit.', 'Wisdom is not putting it in a fruit salad']

# %%
words=[word_tokenize(sent) for sent in sents]
print(words)
# Out:
# [['Knowledge', 'is', 'knowing', 'a', 'tomato', 'is', 'a', 'fruit', '.'], ['Wisdom', 'is', 'not', 'putting', 'it', 'in', 'a', 'fruit', 'salad']]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lakshyasi/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#Stopword Removal
from nltk.corpus import stopwords 
from string import punctuation
customStopWords=set(stopwords.words('english')+list(punctuation))

# %%
wordsWOStopwords=[word for word in word_tokenize(text) if word not in customStopWords]
print(wordsWOStopwords)
# Out:
# ['Knowledge', 'knowing', 'tomato', 'fruit', 'Wisdom', 'putting', 'fruit', 'salad']

# %%
stopwords.words('english')
# Out:
# [u'i',
#  u'me',
#  u'my',
#  u'myself',
#  u'we',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'you',
#  u"you're",
#  u"you've",
#  u"you'll",
#  u"you'd",
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves',
#  u'he',
#  u'him',
#  u'his',
#  u'himself',
#  u'she',
#  u"she's",
#  u'her',
#  u'hers',
#  u'herself',
#  u'it',
#  u"it's",
#  u'its',
#  u'itself',
#  u'they',
#  u'them',
#  u'their',
#  u'theirs',
#  u'themselves',
#  u'what',
#  u'which',
#  u'who',
#  u'whom',
#  u'this',
#  u'that',
#  u"that'll",
#  u'these',
#  u'those',
#  u'am',
#  u'is',
#  u'are',
#  u'was',
#  u'were',
#  u'be',
#  u'been',
#  u'being',
#  u'have',
#  u'has',
#  u'had',
#  u'having',
#  u'do',
#  u'does',
#  u'did',
#  u'doing',
#  u'a',
#  u'an',
#  u'the',
#  u'and',
#  u'but',
#  u'if',
#  u'or',
#  u'because',
#  u'as',
#  u'until',
#  u'while',
#  u'of',
#  u'at',
#  u'by',
#  u'for',
#  u'with',
#  u'about',
#  u'against',
#  u'between',
#  u'into',
#  u'through',
#  u'during',
# ...

# %%
#Stemming
text = "Mary closed on closing night when she was in the mood to close."
from nltk.stem.lancaster import LancasterStemmer
st=LancasterStemmer()
stemmedWords=[st.stem(word) for word in word_tokenize(text)]
print(stemmedWords)
# Out:
# ['mary', 'clos', 'on', 'clos', 'night', 'when', 'she', 'was', 'in', 'the', 'mood', 'to', 'clos', '.']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/lakshyasi/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#POS Tagging
nltk.pos_tag(word_tokenize(text))
# Out:
# [('Mary', 'NNP'),
#  ('closed', 'VBD'),
#  ('on', 'IN'),
#  ('closing', 'NN'),
#  ('night', 'NN'),
#  ('when', 'WRB'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mood', 'NN'),
#  ('to', 'TO'),
#  ('close', 'VB'),
#  ('.', '.')]

# %%
#POS Tagging
text = 'Lee Sedol cannot defeat AlphaGo.'
nltk.pos_tag(word_tokenize(text))
# Out:
# [('Lee', 'NNP'),
#  ('Sedol', 'NNP'),
#  ('can', 'MD'),
#  ('not', 'RB'),
#  ('defeat', 'VB'),
#  ('AlphaGo', 'NNP'),
#  ('.', '.')]

# %%
#Defining Grammar
from nltk import CFG
grammar = CFG.fromstring("""
 S -> NP VP
 VP -> V NP | V NP PP 
 PP -> P NP
 V -> "work" | "defeat" | "walked" | "chased" | "cannot"
 NP -> "Lee" | "Sedol" | "AlphaGo" | Det N | Det N PP
 Det -> "a" | "an" | "the" | "my"
 N -> "man" | "dog" | "cat" | "telescope" | "park"
 P -> "in" | "on" | "with"
 """)

# %%
grammar
# Out:
# <Grammar with 26 productions>

# %%
#Syntactic Parsing
from nltk.parse import RecursiveDescentParser
rd = RecursiveDescentParser(grammar)
sentence = 'the cat chased the dog'.split()
for t in rd.parse(sentence):
     print(t)
# Out:
# (S (NP (Det the) (N cat)) (VP (V chased) (NP (Det the) (N dog))))

# %%
nltk.download('maxent_treebank_pos_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /Users/lakshyasi/nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/lakshyasi/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/lakshyasi/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
#Named Entity Recognition Chunker
from nltk import word_tokenize, pos_tag, ne_chunk
 
sentence = "Lee Sedol cannot defeat AlphaGo"
 
print ne_chunk(pos_tag(word_tokenize(sentence)))
# Out:
# (S
#   (PERSON Lee/NNP)
#   (PERSON Sedol/NNP)
#   can/MD
#   not/RB
#   defeat/VB
#   (ORGANIZATION AlphaGo/NNP))

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/lakshyasi/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
#Entity Resolution
from nltk.corpus import wordnet as wn
for ss in wn.synsets('cool'):
    print(ss, ss.definition())
# Out:
# (Synset('cool.n.01'), u'the quality of being at a refreshingly low temperature')
# (Synset('aplomb.n.01'), u'great coolness and composure under strain')
# (Synset('cool.v.01'), u'make cool or cooler')
# (Synset('cool.v.02'), u'loose heat')
# (Synset('cool.v.03'), u'lose intensity')
# (Synset('cool.a.01'), u'neither warm nor very cold; giving relief from heat')
# (Synset('cool.s.02'), u'marked by calm self-control (especially in trying circumstances); unemotional')
# (Synset('cool.a.03'), u'(color) inducing the impression of coolness; used especially of greens and blues and violets')
# (Synset('cool.a.04'), u'psychologically cool and unenthusiastic; unfriendly or unresponsive or showing dislike')
# (Synset('cool.s.05'), u'(used of a number or sum) without exaggeration or qualification')
# (Synset('cool.s.06'), u'fashionable and attractive at the time; often skilled or socially adept')

# %%
from nltk.wsd import lesk
sense1 = lesk(word_tokenize("The movie has really cool effects"),'cool')
print(sense1, sense1.definition())
# Out:
# (Synset('cool.v.01'), u'make cool or cooler')

# %%
sense2 = lesk(word_tokenize("Dhoni is a cool head on the field"),'cool')
print(sense1, sense2.definition())
# Out:
# (Synset('cool.n.01'), u'the quality of being at a refreshingly low temperature')

# %%
#Coreference : pip install stanfordcorenlp
import stanfordcorenlp
from stanfordcorenlp import StanfordCoreNLP
sNLP = stanfordcorenlp.StanfordCoreNLP()
text = 'A blog post using Stanford CoreNLP Server. Visit www.khalidalnajjar.com for more details.'
print "Annotate:", sNLP.annotate(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-d427522eea6b> in <module>()
#       2 import stanfordcorenlp
#       3 from stanfordcorenlp import StanfordCoreNLP
# ----> 4 sNLP = stanfordcorenlp.StanfordCoreNLP()
#       5 text = 'A blog post using Stanford CoreNLP Server. Visit www.khalidalnajjar.com for more details.'
#       6 print "Annotate:", sNLP.annotate(text)
#
# TypeError: __init__() takes at least 2 arguments (1 given)

# %%
import json
from stanfordcorenlp import StanfordCoreNLP

nlp = StanfordCoreNLP(r'G:\JavaLibraries\stanford-corenlp-full-2017-06-09', quiet=False)
props = {'annotators': 'coref', 'pipelineLanguage': 'en'}

text = 'Barack Obama was born in Hawaii.  He is the president. Obama was elected in 2008.'
result = json.loads(nlp.annotate(text, properties=props))

num, mentions = result['corefs'].items()[0]
for mention in mentions:
    print(mention)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-125-c0b604adb298> in <module>()
#       2 from stanfordcorenlp import StanfordCoreNLP
#       3
# ----> 4 nlp = StanfordCoreNLP(r'G:\JavaLibraries\stanford-corenlp-full-2017-06-09', quiet=False)
#       5 props = {'annotators': 'coref', 'pipelineLanguage': 'en'}
#       6
#
# /Users/lakshyasi/anaconda/lib/python2.7/site-packages/stanfordcorenlp/corenlp.pyc in __init__(self, path_or_host, port, memory, lang, timeout, quiet, logging_level)
#      49             # Check if the dir exists
#      50             if not os.path.isdir(self.path_or_host):
# ---> 51                 raise IOError(str(self.path_or_host) + ' is not a directory.')
#      52             directory = os.path.normpath(self.path_or_host) + os.sep
#      53             self.class_path_dir = directory
#
# ...
